# %% [markdown]
# # Interactive BHJet explorer
#
# Use the sliders to change BHJet parameters and inspect the calculated spectral-energy distribution and jet structure. Rendering the first spectrum can take a moment.

# %%
# %matplotlib widget
from pathlib import Path
import sys

def find_repository_root(start=Path.cwd()):
    for candidate in (start.resolve(), *start.resolve().parents):
        if (candidate / 'examples' / 'interactive' / 'bhjet_explorer.py').is_file():
            return candidate
    raise FileNotFoundError('Open this notebook from a complete modBHJet checkout.')

repository_root = find_repository_root()
sys.path.insert(0, str(repository_root / 'examples' / 'interactive'))
from bhjet_explorer import BHJetExplorer

# %% [markdown]
# ## Explicit parameter overview/list? with a few details?

# %%
explorer = BHJetExplorer(verbosity_level=0, Emin_eV=1e-10, Emax_eV=1e15)
explorer.display()

# %% [markdown]
# Run the next cell to inspect the individual radiation zones.

# %%
# explorer.display_zones()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 explorer.display_zones()
#
# File ~/Desktop/University/phd/bhjet_mod/modBHJet/examples/interactive/bhjet_explorer.py:777, in BHJetExplorer.display_zones(self)
#     774     self._draw_zone(izone)
#     776 self._zone_slider.observe(_on_zone, names="value")
# --> 777 self._draw_zone(self._zone_slider.value)
#     779 display(VBox([
#     780     self._fig_zone.canvas,
#     781     HBox([self._zone_slider, self._zone_label]),
#     782 ]))
#
# File ~/Desktop/University/phd/bhjet_mod/modBHJet/examples/interactive/bhjet_explorer.py:444, in BHJetExplorer._draw_zone(self, izone)
#     442 p_lo = mom_zone[0]  * erg2eV * c_cm_s
#     443 p_hi = mom_zone[-1] * erg2eV * c_cm_s
# --> 444 self._zc_momspan.set_xy([
#     445     [p_lo, 0], [p_lo, 1], [p_hi, 1], [p_hi, 0], [p_lo, 0],
#     446 ])
# ...
